# %% [markdown]
# ### WORKSHOP 3: CANNY EDGE DETECTION
# **Name:** Dhanus karthi S **Reg. No:** 212224230058

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('sec logo.jpg')

# Convert to grayscale.
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

edges = cv2.Canny(img_gray, threshold1 = 180, threshold2 = 200)

plt.figure(figsize = (12,16))
plt.subplot(221); plt.axis("off"); plt.imshow(img[:,:,::-1]); plt.title('Original') 
plt.subplot(222); plt.axis("off"); plt.imshow(img_gray, cmap='gray');      plt.title('Grayscale') img = cv2.imread('sec logo.jpg')
# Out:
#   Cell In[5], line 10
#     plt.subplot(222); plt.axis("off"); plt.imshow(img_gray, cmap='gray');      plt.title('Grayscale') img = cv2.imread('sec logo.jpg')
#                                                                                                       ^
# SyntaxError: invalid syntax
